# %% [markdown]
# Connected to writing-clean-code (3.13.5) (Python 3.13.5)

# %%
import requests

# We need coordinates to get weather data
latitude = 48.85   # Paris latitude
longitude = 2.35   # Paris longitude

# Build the API URL with our parameters
url = f"https://api.open-meteo.com/v1/forecast?latitude={latitude}&longitude={longitude}&current=temperature_2m"

# Make the request
response = requests.get(url)
data = response.json()

print(data)
# Out:
# {'latitude': 48.84, 'longitude': 2.3599997, 'generationtime_ms': 0.032901763916015625, 'utc_offset_seconds': 0, 'timezone': 'GMT', 'timezone_abbreviation': 'GMT', 'elevation': 46.0, 'current_units': {'time': 'iso8601', 'interval': 'seconds', 'temperature_2m': '°C'}, 'current': {'time': '2025-12-17T21:45', 'interval': 900, 'temperature_2m': 7.6}}

# %%
print(data.latitude)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(data.latitude)
#
# AttributeError: 'dict' object has no attribute 'latitude'

# %%
data.keys
# Out:
# <function dict.keys()>

# %%
print(data.keys)
# Out:
# <built-in method keys of dict object at 0x10826e000>

# %%
print(data)
# Out:
# {'latitude': 48.84, 'longitude': 2.3599997, 'generationtime_ms': 0.032901763916015625, 'utc_offset_seconds': 0, 'timezone': 'GMT', 'timezone_abbreviation': 'GMT', 'elevation': 46.0, 'current_units': {'time': 'iso8601', 'interval': 'seconds', 'temperature_2m': '°C'}, 'current': {'time': '2025-12-17T21:45', 'interval': 900, 'temperature_2m': 7.6}}

# %%
print(data[latitude])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(data[latitude])
#
# KeyError: 48.85

# %%
latitude
# Out:
# 48.85
